# %% [markdown]
# # Load dataset

# %%
import pandas as pd

df = pd.read_csv("CC_GENERAL.csv")
df
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10001    40.900749           0.818182      95.40              0.00
# 1     C10002  3202.467416           0.909091       0.00              0.00
# 2     C10003  2495.148862           1.000000     773.17            773.17
# 3     C10004  1666.670542           0.636364    1499.00           1499.00
# 4     C10005   817.714335           1.000000      16.00             16.00
# ...      ...          ...                ...        ...               ...
# 8945  C19186    28.493517           1.000000     291.12              0.00
# 8946  C19187    19.183215           1.000000     300.00              0.00
# 8947  C19188    23.398673           0.833333     144.40              0.00
# 8948  C19189    13.457564           0.833333       0.00              0.00
# 8949  C19190   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# ...

# %%
df.describe()
# Out:
#             BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count   8950.000000        8950.000000   8950.000000       8950.000000
# mean    1564.474828           0.877271   1003.204834        592.437371
# std     2081.531879           0.236904   2136.634782       1659.887917
# min        0.000000           0.000000      0.000000          0.000000
# 25%      128.281915           0.888889     39.635000          0.000000
# 50%      873.385231           1.000000    361.280000         38.000000
# 75%     2054.140036           1.000000   1110.130000        577.405000
# max    19043.138560           1.000000  49039.570000      40761.250000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             8950.000000   8950.000000          8950.000000
# mean               411.067645    978.871112             0.490351
# std                904.338115   2097.163877             0.401371
# min                  0.000000      0.000000             0.000000
# ...

# %%
df.isnull().sum()
# Out:
# CUST_ID                               0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
df['CREDIT_LIMIT'].fillna(df['CREDIT_LIMIT'].mean(), inplace=True)
df['MINIMUM_PAYMENTS'].fillna(df['MINIMUM_PAYMENTS'].mean(), inplace=True)
df.drop(["CUST_ID"], axis=1, inplace=True)
df.isnull().sum().sum()
# Out:
# 0

# %%
import matplotlib.pyplot as plt
import seaborn as sns
def plot_correlation_map(df):
    corr = df.corr()
    s , ax = plt.subplots(figsize = (12 , 10))
    cmap = sns.diverging_palette(220 , 10 , as_cmap = True)
    s = sns.heatmap(
        corr, 
        cmap = cmap,
        square=True, 
        cbar_kws={ 'shrink' : .9 }, 
        ax=ax, 
        annot = True, 
        annot_kws = { 'fontsize' : 12 }
        )
plot_correlation_map(df)

# %% [markdown]
# # Hierarchical clustering

# %%
from sklearn.preprocessing import StandardScaler, normalize

# Standardize data
scaler = StandardScaler() 
scaled_df = scaler.fit_transform(df) 
  
# Normalizing the Data 
normalized_df = normalize(scaled_df) 
 
# Converting the numpy array into a pandas DataFrame 
normalized_df = pd.DataFrame(normalized_df)
# Out:
#       0
# 0     0
# 1     2
# 2     1
# 3     0
# 4     0
# ...  ..
# 8945  2
# 8946  2
# 8947  2
# 8948  2
# 8949  2
#
# [8950 rows x 1 columns]

# %%
from sklearn.cluster import AgglomerativeClustering
model=AgglomerativeClustering(n_clusters=3, affinity='euclidean', linkage='complete')
clust_labels=model.fit_predict(normalized_df)
agglomerative=pd.DataFrame(clust_labels)
agglomerative
# Out:
#       0
# 0     0
# 1     0
# 2     1
# 3     0
# 4     0
# ...  ..
# 8945  0
# 8946  0
# 8947  0
# 8948  0
# 8949  0
#
# [8950 rows x 1 columns]

# %% [markdown]
# # Plot the clusters

# %%
fig =plt.figure()
ax = fig.add_subplot(111)
scatter = ax.scatter (normalized_df[13] , normalized_df[2] , c=agglomerative[0], s=50)
ax.set_title("Agglomerative Clutering")
ax.set_xlabel("PAYMENTS")
ax.set_ylabel("PURCHASES")
plt.colorbar(scatter)

# %% [markdown]
# # Plot the dendrogram

# %%
import scipy.cluster.hierarchy as shc
plt.figure(figsize=(10,7))
plt.title("Dendrograms")
dend=shc.dendrogram(shc.linkage(normalized_df, method="complete"))

# %% [markdown]
# # K-means clustering

# %%
from sklearn.cluster import KMeans
kmeans=KMeans(n_clusters=3, random_state=0)
kmeans.fit(normalized_df)
labels=pd.DataFrame(kmeans.labels_)
labels
# Out:
#       0
# 0     2
# 1     1
# 2     0
# 3     2
# 4     2
# ...  ..
# 8945  0
# 8946  0
# 8947  0
# 8948  2
# 8949  0
#
# [8950 rows x 1 columns]

# %% [markdown]
# #  Select the best k value using the elbow method

# %%
sum_of_squared_distances = []
K = range(1, 15)
for k in K:
    km = KMeans(n_clusters=k)
    km = km.fit(normalized_df)
    sum_of_squared_distances.append(km.inertia_)
    
plt.plot(K, sum_of_squared_distances, 'bx-')
plt.xlabel('k')
plt.ylabel('sum_of_squared_distances')
plt.show()

# %% [markdown]
# Thanks to the elbow method the optimal k value is 5.

# %%
kmeans=KMeans(n_clusters=5, random_state=0)
kmeans.fit(normalized_df)
labels=pd.DataFrame(kmeans.labels_)
labels

plt.scatter(normalized_df[13], normalized_df[2], c = labels)
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=300, c='red', label = 'Centroids')
plt.title("K-means Clutering")
plt.xlabel("PAYMENTS")
plt.ylabel("PURCHASES")
plt.show()

# %% [markdown]
# # Compare the two results

# %%
# Hierarchical clustering
model=AgglomerativeClustering(n_clusters=5, affinity='euclidean', linkage='complete')
clust_labels=model.fit_predict(normalized_df)
agglomerative=pd.DataFrame(clust_labels)
agglomerative

fig =plt.figure()
ax = fig.add_subplot(111)
scatter = ax.scatter (normalized_df[13] , normalized_df[2] , c=agglomerative[0], s=50)
ax.set_title("Agglomerative Clutering")
ax.set_xlabel("PAYMENTS")
ax.set_ylabel("PURCHASES")
plt.show()

# K-means clustering
kmeans=KMeans(n_clusters=5, random_state=0)
kmeans.fit(normalized_df)
labels=pd.DataFrame(kmeans.labels_)
labels

plt.scatter(normalized_df[13], normalized_df[2], c = labels)
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=300, c='red', label = 'Centroids')
plt.title("K-means Clutering")
plt.xlabel("PAYMENTS")
plt.ylabel("PURCHASES")
plt.show()

# %% [markdown]
# The hierarchical clustering and k-means clustering plots are similar.

# %% [markdown]
# # Another validation metric => PCA

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
principal_comp = pca.fit_transform(normalized_df)
pca_df = pd.DataFrame(data=principal_comp,columns=['pca1','pca2'])
labels = kmeans.labels_
pca_df = pd.concat([pca_df,pd.DataFrame({'cluster':labels})], axis = 1)
plt.figure(figsize=(10,10))
plt.style.use('ggplot')
ax = sns.scatterplot(x="pca1", y="pca2", hue = "cluster", data = pca_df, palette =['red','green','blue','black','yellow'])
plt.show()
